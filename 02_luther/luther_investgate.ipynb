# %%
import pickle

with open("my_data_2000_2014_02.pkl", 'r') as picklefile: 
    raw_data1 = pickle.load(picklefile)

# %%
raw_data1.items()[:20]
# Out:
# [('/title/tt0388838/',
#   {'country': u'France',
#    'director': u'Olivier Assayas',
#    'duration': 'PT90M',
#    'genres': ['Drama', 'Music'],
#    'gross': u'$136,007',
#    'language': u'French',
#    'lead': u'Maggie Cheung',
#    'metacritic': '75/100',
#    'num_reviews': '37',
#    'num_users': '3,810',
#    'opening': u'$5,700        \n\n      (Hong Kong)',
#    'rating': 'R',
#    'release': '2004-09-01',
#    'studio': u'Rectangle Productions',
#    'title': u'Clean',
#    'user_score': 6.9}),
#  ('/title/tt0368794/',
#   {'country': u'USA',
#    'director': u'Todd Haynes',
#    'duration': 'PT135M',
#    'genres': ['Biography', 'Drama', 'Music'],
#    'gross': u'$4,017,609',
#    'language': u'English',
#    'lead': u'Christian Bale',
#    'metacritic': '73/100',
#    'num_reviews': '228',
#    'num_users': '45,629',
#    'opening': u'$730,819        \n\n      (USA)',
#    'rating': 'R',
#    'release': '2007-12-07',
#    'studio': u'Killer Films',
# ...
